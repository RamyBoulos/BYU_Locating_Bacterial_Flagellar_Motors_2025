# %% [markdown]
# # YOLOv8 Training Notebook
#
# This notebook demonstrates how to train a YOLOv8 model using the Ultralytics API in a Jupyter environment.

# %% [markdown]
# ## 1. Install Dependencies

# %%
import os
import sys

# Add project root to system path (for relative imports to work)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src import config

# %% [markdown]
# ## 2. Prepare Data Configuration (`data.yaml`)
# Define paths, number of classes, and class names.

# %%
import yaml

data_cfg = {
    'path': config.YOLO_DATA_DIR,
    'train': "images/train",
    'val': "images/val",
    'nc': 1,         # number of classes
    'names': ['motor']  # class names
}

with open(f'{config.SRC}/data.yaml', 'w') as f:
    yaml.dump(data_cfg, f)

print('data.yaml written successfully')
# Out:
# data.yaml written successfully

# %% [markdown]
# ## 3. (Optional) Custom Hyperparameters (`hyp.yaml`)
# Adjust settings to handle class imbalance (focal loss, mosaic, mixup).

# %%
import yaml

hyp_params = {
    'lr0': 0.01,
    'box': 0.05,
    'obj': 1.0,
    'cls': 0.5,
    'fl_gamma': 1.5,
    'label_smoothing': 0.0,
    'mosaic': 1.0,
    'mixup': 0.5
}

with open(f'{config.SRC}/hyp.yaml', 'w') as f:
    yaml.dump(hyp_params, f)

print('hyp.yaml written successfully')

# %% [markdown]
# ## 4. Train the YOLOv8 Model
# Use the Ultralytics `YOLO` class to start training.

# %%
from ultralytics import YOLO  # ultralytics>=8.0

# Load a pretrained YOLOv8 model
model = YOLO('yolov8n.pt')
print(f'{config.SRC}/data.yaml')

results = model.train(
    data=f'data.yaml',           # dataset config path
    epochs=50,                  # total epochs (int)
    batch=16,                   # batch size (int or float for auto)
    imgsz=640,                  # image size (int or list)
    device='cpu',              # device: 'cpu', GPU index, or list of indices
    workers=8,                  # dataloader workers (int)
    optimizer='SGD',            # optimizer: 'auto', 'SGD', 'Adam', etc.
    lr0=0.01,                   # initial learning rate
    lrf=0.01,                   # final lr = lr0 * lrf
    momentum=0.937,             # momentum for SGD or beta1 for Adam
    weight_decay=0.0005,        # L2 regularization
    patience=10,                # early stopping patience (int)
    save=True,                  # save checkpoints
    save_period=-1,             # checkpoint frequency (epochs)
    cache=False,                # cache mode: False, 'ram', or 'disk'
    project=config.YOLO_RESULT,       # save results to runs/train/
    name='motor_detection',     # run name
    exist_ok=True,              # overwrite existing outputs
    pretrained=True,            # use pretrained weights
    seed=42,                    # random seed
    deterministic=True,         # deterministic training
    single_cls=False,           # single-class training
    rect=False,                 # rectangular training
    multi_scale=False,          # multi-scale training
    cos_lr=False,               # cosine LR scheduler
    close_mosaic=10,            # disable mosaic in final epochs
    resume=False,               # resume from last checkpoint
    amp=True,                   # automatic mixed precision
    warmup_epochs=3.0,          # warmup epochs
    warmup_momentum=0.8,        # warmup momentum
    warmup_bias_lr=0.1,         # warmup bias lr
    box=7.5,                    # box loss gain
    cls=0.5,                    # classification loss gain
    dfl=1.5,                    # distribution focal loss gain
    val=True,                   # validate during training
    plots=False                 # save plots
)

print(results)
# Out:
# /Users/kereminci/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/src/data.yaml
# Ultralytics 8.3.160 🚀 Python-3.13.3 torch-2.7.1 CPU (Apple M1)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'coco.yaml' images not found, missing path '/Users/kereminci/Desktop/cms-team/ultralytics_yolo/datasets/coco/val2017.txt'
# Downloading http://images.cocodataset.org/zips/train2017.zip to '/Users/kereminci/Desktop/cms-team/ultralytics_yolo/datasets/coco/images/train2017.zip'...
# Downloading http://images.cocodataset.org/zips/val2017.zip to '/Users/kereminci/Desktop/cms-team/ultralytics_yolo/datasets/coco/images/val2017.zip'...
# Downloading http://images.cocodataset.org/zips/test2017.zip to '/Users/kereminci/Desktop/cms-team/ultralytics_yolo/datasets/coco/images/test2017.zip'...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/engine/trainer.py:607, in BaseTrainer.get_dataset(self)
#     601 elif self.args.data.rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     602     "detect",
#     603     "segment",
#     604     "pose",
#     605     "obb",
#     606 }:
# --> 607     data = check_det_dataset(self.args.data)
#     608     if "yaml_file" in data:
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/data/utils.py:472, in check_det_dataset(dataset, autodownload)
#     471 else:  # python script
# --> 472     exec(s, {"yaml": data})
#     473 dt = f"({round(time.time() - t, 1)}s)"
#
# File <string>:17
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/utils/downloads.py:512, in download(url, dir, unzip, delete, curl, threads, retry, exist_ok)
#     511 with ThreadPool(threads) as pool:
# --> 512     pool.map(
#     513         lambda x: safe_download(
#     514             url=x[0],
#     515             dir=x[1],
#     516             unzip=unzip,
#     517             delete=delete,
#     518             curl=curl,
#     519             retry=retry,
#     520             exist_ok=exist_ok,
#     521             progress=threads <= 1,
#     522         ),
#     523         zip(url, repeat(dir)),
#     524     )
#     525     pool.close()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     363 '''
#     364 Apply `func` to each element in `iterable`, collecting the results
#     365 in a list that is returned.
#     366 '''
# --> 367 return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     773 else:
# --> 774     raise self._value
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py:48, in mapstar(args)
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/utils/downloads.py:513, in download.<locals>.<lambda>(x)
#     511 with ThreadPool(threads) as pool:
#     512     pool.map(
# --> 513         lambda x: safe_download(
#     514             url=x[0],
#     515             dir=x[1],
#     516             unzip=unzip,
#     517             delete=delete,
#     518             curl=curl,
#     519             retry=retry,
#     520             exist_ok=exist_ok,
#     521             progress=threads <= 1,
#     522         ),
#     523         zip(url, repeat(dir)),
#     524     )
#     525     pool.close()
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/utils/downloads.py:340, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     339 f.parent.mkdir(parents=True, exist_ok=True)  # make directory if missing
# --> 340 check_disk_space(url, path=f.parent)
#     341 curl_installed = shutil.which("curl")
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/utils/downloads.py:242, in check_disk_space(url, path, sf, hard)
#     241 if hard:
# --> 242     raise MemoryError(text)
#     243 LOGGER.warning(text)
#
# MemoryError: Insufficient free disk space 1.2 GB < 27.013 GB required, Please free 25.9 GB additional disk space and try again.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 7
#       4 model = YOLO('yolov8n.pt')
#       5 print(f'{config.SRC}/data.yaml')
# ----> 7 results = model.train(
#       8
#       9 )
#      11 print(results)
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/engine/model.py:793, in Model.train(self, trainer, **kwargs)
#     790 if args.get("resume"):
#     791     args["resume"] = self.ckpt_path
# --> 793 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     794 if not args.get("resume"):  # manually set model only if not resuming
#     795     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/engine/trainer.py:153, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     151 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     152 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 153     self.data = self.get_dataset()
#     155 self.ema = None
#     157 # Optimization utils init
#
# File ~/Desktop/cms-team/BYU_Locating_Bacterial_Flagellar_Motors_2025/.venv/lib/python3.13/site-packages/ultralytics/engine/trainer.py:611, in BaseTrainer.get_dataset(self)
#     609             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     610 except Exception as e:
# --> 611     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     612 if self.args.single_cls:
#     613     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'coco.yaml' error ❌ Insufficient free disk space 1.2 GB < 27.013 GB required, Please free 25.9 GB additional disk space and try again.
